# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
#import requests
#from config import weather_api_key
#from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cc315556528a1788f07d46e083a408e

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low =-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low =-100.000, high=100.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cc315556528a1788f07d46e083a408e

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather['sys']['country']  
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                    
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jacobina
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | tocopilla
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | vagur
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | richards bay
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | big rapids
# Processing Record 13 of Set 1 | vierzon
# Processing Record 14 of Set 1 | summerside
# Processing Record 15 of Set 1 | henderson
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | avallon
# Processing Record 18 of Set 1 | shihezi
# Processing Record 19 of Set 1 | chapais
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | lima
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | kaltasy
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | maldonado
# Processing Record 28 of Set 1 | nouadhibou
# Processing Record 29 of Set 1 | gambela
# Processing Record 30 of Set 1 | deep river
# Processing Record 31 of Set 1 | tapes
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | yumen
# Processing Record 35 of Set 1 | puri
# Processing Record 36 of Set 1 | nuuk
# Processing Record 37 of Set 1 | avesta
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | ambilobe
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | abnub
# Processing Record 43 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | kolokani
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | shahr-e babak
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | mwinilunga
# Processing Record 50 of Set 1 | marienburg
# Processing Record 1 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 2 | san carlos de bariloche
# Processing Record 4 of Set 2 | luba
# Processing Record 5 of Set 2 | tipacoque
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | kibala
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | teya
# Processing Record 11 of Set 2 | ponta delgada
# Processing Record 12 of Set 2 | bandarbeyla
# Processing Record 13 of Set 2 | asyut
# Processing Record 14 of Set 2 | visconde do rio branco
# Processing Record 15 of Set 2 | puerto leguizamo
# Processing Record 16 of Set 2 | masvingo
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | sayan
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | champerico
# Processing Record 22 of Set 2 | humaita
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 25 of Set 2 | kulykivka
# Processing Record 26 of Set 2 | the valley
# Processing Record 27 of Set 2 | lodwar
# Processing Record 28 of Set 2 | sept-iles
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | kismayo
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | owando
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | cheyur
# City not found. Skipping...
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | kharp
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | sioux lookout
# Processing Record 41 of Set 2 | tome
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | pontes e lacerda
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | lannion
# Processing Record 46 of Set 2 | palmares do sul
# Processing Record 47 of Set 2 | maua
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | kajaani
# Processing Record 2 of Set 3 | floro
# Processing Record 3 of Set 3 | tromso
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | henties bay
# Processing Record 7 of Set 3 | marquard
# Processing Record 8 of Set 3 | grindavik
# Processing Record 9 of Set 3 | sibolga
# Processing Record 10 of Set 3 | bafoulabe
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | muscle shoals
# Processing Record 13 of Set 3 | kyrylivka
# Processing Record 14 of Set 3 | itaporanga
# Processing Record 15 of Set 3 | abu dhabi
# Processing Record 16 of Set 3 | bemidji
# Processing Record 17 of Set 3 | naryan-mar
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | ancud
# Processing Record 20 of Set 3 | beroroha
# Processing Record 21 of Set 3 | lavra
# Processing Record 22 of Set 3 | borama
# City not found. Skipping...
# Processing Record 23 of Set 3 | arkhangelsk
# Processing Record 24 of Set 3 | beloit
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | thornhill
# Processing Record 27 of Set 3 | berlevag
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | moultonborough
# Processing Record 30 of Set 3 | tambopata
# Processing Record 31 of Set 3 | senekal
# Processing Record 32 of Set 3 | aksarka
# Processing Record 33 of Set 3 | abu samrah
# Processing Record 34 of Set 3 | codrington
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | beyneu
# Processing Record 38 of Set 3 | tripoli
# Processing Record 39 of Set 3 | sydney
# Processing Record 40 of Set 3 | staryy nadym
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | besancon
# Processing Record 43 of Set 3 | barwaha
# City not found. Skipping...
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | sinjar
# Processing Record 47 of Set 3 | olden
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | raudeberg
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | prieska
# Processing Record 2 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | heinola
# Processing Record 6 of Set 4 | hami
# Processing Record 7 of Set 4 | krasnoselkup
# Processing Record 8 of Set 4 | halifax
# Processing Record 9 of Set 4 | saraland
# Processing Record 10 of Set 4 | nuevitas
# Processing Record 11 of Set 4 | fort smith
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | albany
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | barvinkove
# Processing Record 16 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 4 | santa fe
# Processing Record 18 of Set 4 | hualahuises
# Processing Record 19 of Set 4 | uusikaupunki
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | margate
# Processing Record 22 of Set 4 | galatas
# Processing Record 23 of Set 4 | malazgirt
# Processing Record 24 of Set 4 | dikson
# Processing Record 25 of Set 4 | lengede
# Processing Record 26 of Set 4 | leshukonskoye
# Processing Record 27 of Set 4 | nizhniy odes
# Processing Record 28 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 4 | manono
# Processing Record 30 of Set 4 | quatre cocos
# Processing Record 31 of Set 4 | bitkine
# Processing Record 32 of Set 4 | atar
# Processing Record 33 of Set 4 | alice town
# Processing Record 34 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | inndyr
# Processing Record 36 of Set 4 | dudinka
# Processing Record 37 of Set 4 | mwandiga
# Processing Record 38 of Set 4 | acajutla
# Processing Record 39 of Set 4 | kaduna
# Processing Record 40 of Set 4 | damaturu
# Processing Record 41 of Set 4 | calamar
# Processing Record 42 of Set 4 | ikalamavony
# Processing Record 43 of Set 4 | feijo
# Processing Record 44 of Set 4 | kamenka
# Processing Record 45 of Set 4 | varhaug
# Processing Record 46 of Set 4 | port antonio
# Processing Record 47 of Set 4 | taunggyi
# Processing Record 48 of Set 4 | valparaiso
# Processing Record 49 of Set 4 | bahia honda
# Processing Record 50 of Set 4 | wadi maliz
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | juba
# Processing Record 3 of Set 5 | lypova dolyna
# Processing Record 4 of Set 5 | mastic beach
# Processing Record 5 of Set 5 | saint-augustin
# Processing Record 6 of Set 5 | kitob
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | mar del plata
# Processing Record 9 of Set 5 | waynesville
# Processing Record 10 of Set 5 | tucuma
# Processing Record 11 of Set 5 | bud
# Processing Record 12 of Set 5 | oistins
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | strezhevoy
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | serta
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | san ramon
# Processing Record 19 of Set 5 | altamira
# Processing Record 20 of Set 5 | castro
# Processing Record 21 of Set 5 | vila do maio
# Processing Record 22 of Set 5 | sao felix do xingu
# Processing Record 23 of Set 5 | tiznit
# Processing Record 24 of Set 5 | yining
# Processing Record 25 of Set 5 | willowmore
# Processing Record 26 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 5 | izhma
# Processing Record 28 of Set 5 | plouzane
# Processing Record 29 of Set 5 | kathmandu
# Processing Record 30 of Set 5 | pimentel
# Processing Record 31 of Set 5 | gola bazar
# Processing Record 32 of Set 5 | ilo
# Processing Record 33 of Set 5 | amapa
# Processing Record 34 of Set 5 | road town
# Processing Record 35 of Set 5 | ovalle
# Processing Record 36 of Set 5 | kisangani
# Processing Record 37 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | wadhwan
# City not found. Skipping...
# Processing Record 40 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | bonfim
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | malanje
# Processing Record 45 of Set 5 | goderich
# Processing Record 46 of Set 5 | mecca
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | san jose
# Processing Record 49 of Set 5 | volary
# Processing Record 50 of Set 5 | mana
# Processing Record 1 of Set 6 | salina
# Processing Record 2 of Set 6 | mangalam
# Processing Record 3 of Set 6 | iralaya
# Processing Record 4 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 5 of Set 6 | emilio carranza
# Processing Record 6 of Set 6 | japura
# Processing Record 7 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | houma
# Processing Record 10 of Set 6 | bosaso
# Processing Record 11 of Set 6 | muisne
# Processing Record 12 of Set 6 | marrakesh
# Processing Record 13 of Set 6 | hualmay
# Processing Record 14 of Set 6 | bolu
# Processing Record 15 of Set 6 | hisua
# Processing Record 16 of Set 6 | cadereyta
# Processing Record 17 of Set 6 | sokolo
# Processing Record 18 of Set 6 | saint george
# Processing Record 19 of Set 6 | antofagasta
# Processing Record 20 of Set 6 | irituia
# Processing Record 21 of Set 6 | stornoway
# Processing Record 22 of Set 6 | salalah
# Processing Record 23 of Set 6 | peniche
# Processing Record 24 of Set 6 | san ignacio
# Processing Record 25 of Set 6 | bara
# Processing Record 26 of Set 6 | oranjestad
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | kapustin yar-1
# City not found. Skipping...
# Processing Record 29 of Set 6 | labytnangi
# Processing Record 30 of Set 6 | bathsheba
# Processing Record 31 of Set 6 | tessalit
# Processing Record 32 of Set 6 | torres
# Processing Record 33 of Set 6 | luanda
# Processing Record 34 of Set 6 | rawson
# Processing Record 35 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 36 of Set 6 | viedma
# Processing Record 37 of Set 6 | turan
# Processing Record 38 of Set 6 | qasigiannguit
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | najran
# Processing Record 41 of Set 6 | los llanos de aridane
# Processing Record 42 of Set 6 | lubango
# Processing Record 43 of Set 6 | kanniyakumari
# Processing Record 44 of Set 6 | gobabis
# Processing Record 45 of Set 6 | sidi ali
# Processing Record 46 of Set 6 | port-cartier
# Processing Record 47 of Set 6 | gubkinskiy
# Processing Record 48 of Set 6 | buraydah
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | lebu
# Processing Record 1 of Set 7 | vieux-habitants
# Processing Record 2 of Set 7 | francisco sa
# Processing Record 3 of Set 7 | ciudad bolivar
# Processing Record 4 of Set 7 | taywarah
# Processing Record 5 of Set 7 | beloha
# Processing Record 6 of Set 7 | el seibo
# Processing Record 7 of Set 7 | marawi
# Processing Record 8 of Set 7 | kasempa
# Processing Record 9 of Set 7 | trebukhiv
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | merritt island
# Processing Record 12 of Set 7 | birjand
# Processing Record 13 of Set 7 | paamiut
# Processing Record 14 of Set 7 | vadinsk
# Processing Record 15 of Set 7 | tandil
# Processing Record 16 of Set 7 | marsa matruh
# Processing Record 17 of Set 7 | astara
# Processing Record 18 of Set 7 | axim
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | necochea
# Processing Record 21 of Set 7 | balkanabat
# Processing Record 22 of Set 7 | xonacatlan
# Processing Record 23 of Set 7 | anloga
# Processing Record 24 of Set 7 | podosinovets
# Processing Record 25 of Set 7 | shelburne
# Processing Record 26 of Set 7 | padang
# Processing Record 27 of Set 7 | chatakonda
# Processing Record 28 of Set 7 | gornopravdinsk
# Processing Record 29 of Set 7 | nanyuki
# Processing Record 30 of Set 7 | itacurubi del rosario
# Processing Record 31 of Set 7 | shar
# Processing Record 32 of Set 7 | itarema
# Processing Record 33 of Set 7 | la rioja
# Processing Record 34 of Set 7 | san bartolome de tirajana
# Processing Record 35 of Set 7 | klaksvik
# Processing Record 36 of Set 7 | maceio
# Processing Record 37 of Set 7 | gaya
# Processing Record 38 of Set 7 | brzeg
# Processing Record 39 of Set 7 | kyaikto
# Processing Record 40 of Set 7 | muravlenko
# Processing Record 41 of Set 7 | karaton
# Processing Record 42 of Set 7 | benguela
# Processing Record 43 of Set 7 | tabou
# Processing Record 44 of Set 7 | tura
# Processing Record 45 of Set 7 | mangaratiba
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | itaocara
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | le port
# Processing Record 50 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 8 | buchanan
# Processing Record 2 of Set 8 | uvalde
# Processing Record 3 of Set 8 | imbituba
# Processing Record 4 of Set 8 | utica
# Processing Record 5 of Set 8 | takoradi
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | oranjemund
# Processing Record 8 of Set 8 | kungurtug
# Processing Record 9 of Set 8 | vestmanna
# Processing Record 10 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 8 | acarau
# Processing Record 12 of Set 8 | meulaboh
# Processing Record 13 of Set 8 | sorland
# Processing Record 14 of Set 8 | nieuw amsterdam
# Processing Record 15 of Set 8 | greenwood
# Processing Record 16 of Set 8 | krutinka
# Processing Record 17 of Set 8 | kidal
# Processing Record 18 of Set 8 | nioro
# Processing Record 19 of Set 8 | quebrangulo
# Processing Record 20 of Set 8 | nueva loja
# Processing Record 21 of Set 8 | wattegama
# Processing Record 22 of Set 8 | marinette
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | khash
# Processing Record 25 of Set 8 | serenje
# Processing Record 26 of Set 8 | sundargarh
# Processing Record 27 of Set 8 | purpe
# Processing Record 28 of Set 8 | bayan
# Processing Record 29 of Set 8 | divnogorsk
# Processing Record 30 of Set 8 | aleksandrov gay
# Processing Record 31 of Set 8 | chomun
# City not found. Skipping...
# Processing Record 32 of Set 8 | dabhol
# Processing Record 33 of Set 8 | sarkand
# Processing Record 34 of Set 8 | pencaitland
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | zafarwal
# Processing Record 37 of Set 8 | halmstad
# Processing Record 38 of Set 8 | saint-leu
# Processing Record 39 of Set 8 | sur
# Processing Record 40 of Set 8 | grand-santi
# Processing Record 41 of Set 8 | key largo
# Processing Record 42 of Set 8 | kyzyl-suu
# Processing Record 43 of Set 8 | urumqi
# Processing Record 44 of Set 8 | lagoa
# Processing Record 45 of Set 8 | chapleau
# Processing Record 46 of Set 8 | hambantota
# Processing Record 47 of Set 8 | centerville
# Processing Record 48 of Set 8 | bridgetown
# Processing Record 49 of Set 8 | talah
# City not found. Skipping...
# Processing Record 50 of Set 8 | taoudenni
# Processing Record 1 of Set 9 | visnes
# Processing Record 2 of Set 9 | knyaginino
# Processing Record 3 of Set 9 | huancavelica
# Processing Record 4 of Set 9 | winder
# Processing Record 5 of Set 9 | coihaique
# Processing Record 6 of Set 9 | punta gorda
# Processing Record 7 of Set 9 | akyab
# Processing Record 8 of Set 9 | at-bashi
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | tubmanburg
# Processing Record 11 of Set 9 | tahoua
# Processing Record 12 of Set 9 | vardo
# Processing Record 13 of Set 9 | bambous virieux
# Processing Record 14 of Set 9 | metz
# Processing Record 15 of Set 9 | bristol
# Processing Record 16 of Set 9 | turka
# Processing Record 17 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 18 of Set 9 | starobaltachevo
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | sandwick
# Processing Record 21 of Set 9 | rafai
# Processing Record 22 of Set 9 | mitu
# Processing Record 23 of Set 9 | sechura
# Processing Record 24 of Set 9 | sheltozero
# Processing Record 25 of Set 9 | hurghada
# Processing Record 26 of Set 9 | jaslo
# Processing Record 27 of Set 9 | bondo
# Processing Record 28 of Set 9 | orikhiv
# Processing Record 29 of Set 9 | umm lajj
# Processing Record 30 of Set 9 | racine
# Processing Record 31 of Set 9 | pinega
# Processing Record 32 of Set 9 | salinas
# Processing Record 33 of Set 9 | kudahuvadhoo
# Processing Record 34 of Set 9 | newark
# Processing Record 35 of Set 9 | aseri
# Processing Record 36 of Set 9 | lieksa
# Processing Record 37 of Set 9 | manta
# Processing Record 38 of Set 9 | kang
# Processing Record 39 of Set 9 | esmeraldas
# Processing Record 40 of Set 9 | lyngseidet
# Processing Record 41 of Set 9 | saint-pierre
# Processing Record 42 of Set 9 | misratah
# Processing Record 43 of Set 9 | yutsa
# Processing Record 44 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 45 of Set 9 | barhi
# Processing Record 46 of Set 9 | cockburn town
# Processing Record 47 of Set 9 | honningsvag
# Processing Record 48 of Set 9 | tatarskaya pishlya
# Processing Record 49 of Set 9 | aktau
# Processing Record 50 of Set 9 | koungou
# Processing Record 1 of Set 10 | badin
# Processing Record 2 of Set 10 | teknaf
# Processing Record 3 of Set 10 | bubaque
# Processing Record 4 of Set 10 | chongwe
# Processing Record 5 of Set 10 | beya
# Processing Record 6 of Set 10 | banda aceh
# Processing Record 7 of Set 10 | presidencia roque saenz pena
# Processing Record 8 of Set 10 | carballo
# Processing Record 9 of Set 10 | jiwani
# Processing Record 10 of Set 10 | dimbokro
# Processing Record 11 of Set 10 | assai
# Processing Record 12 of Set 10 | teguise
# Processing Record 13 of Set 10 | porto novo
# Processing Record 14 of Set 10 | liwale
# Processing Record 15 of Set 10 | ambam
# Processing Record 16 of Set 10 | ugoofaaru
# Processing Record 17 of Set 10 | lingsugur
# Processing Record 18 of Set 10 | praia da vitoria
# Processing Record 19 of Set 10 | zykovo
# Processing Record 20 of Set 10 | uvira
# Processing Record 21 of Set 10 | wilmington
# Processing Record 22 of Set 10 | sabya
# Processing Record 23 of Set 10 | shurob
# Processing Record 24 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 25 of Set 10 | loandjili
# Processing Record 26 of Set 10 | prainha
# Processing Record 27 of Set 10 | dalaba
# Processing Record 28 of Set 10 | liverpool
# Processing Record 29 of Set 10 | agropoli
# Processing Record 30 of Set 10 | shubarshi
# Processing Record 31 of Set 10 | thinadhoo
# Processing Record 32 of Set 10 | canutama
# Processing Record 33 of Set 10 | toamasina
# Processing Record 34 of Set 10 | grand gaube
# Processing Record 35 of Set 10 | the pas
# Processing Record 36 of Set 10 | skelleftea
# Processing Record 37 of Set 10 | berbera
# Processing Record 38 of Set 10 | dwarka
# Processing Record 39 of Set 10 | grootfontein
# Processing Record 40 of Set 10 | ushtobe
# Processing Record 41 of Set 10 | bagan
# Processing Record 42 of Set 10 | hobyo
# Processing Record 43 of Set 10 | sulzbach-rosenberg
# Processing Record 44 of Set 10 | santarem
# Processing Record 45 of Set 10 | eirunepe
# Processing Record 46 of Set 10 | pochutla
# Processing Record 47 of Set 10 | faya
# Processing Record 48 of Set 10 | melilla
# Processing Record 49 of Set 10 | zelenogorskiy
# Processing Record 50 of Set 10 | kayerkan
# Processing Record 1 of Set 11 | perpignan
# Processing Record 2 of Set 11 | zhezkazgan
# Processing Record 3 of Set 11 | pisco
# Processing Record 4 of Set 11 | mattawa
# Processing Record 5 of Set 11 | kasongo-lunda
# Processing Record 6 of Set 11 | cabedelo
# Processing Record 7 of Set 11 | nanded
# City not found. Skipping...
# Processing Record 8 of Set 11 | warrensburg
# Processing Record 9 of Set 11 | vila franca do campo
# Processing Record 10 of Set 11 | tarko-sale
# Processing Record 11 of Set 11 | freeport
# Processing Record 12 of Set 11 | praia
# Processing Record 13 of Set 11 | mamlyutka
# Processing Record 14 of Set 11 | pijijiapan
# Processing Record 15 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 11 | weligama
# Processing Record 17 of Set 11 | rudsar
# Processing Record 18 of Set 11 | tshikapa
# Processing Record 19 of Set 11 | lagunillas
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | saint-michel-des-saints
# Processing Record 22 of Set 11 | garm
# City not found. Skipping...
# Processing Record 23 of Set 11 | kulhudhuffushi
# Processing Record 24 of Set 11 | laela
# Processing Record 25 of Set 11 | shache
# Processing Record 26 of Set 11 | zaysan
# Processing Record 27 of Set 11 | veraval
# Processing Record 28 of Set 11 | isla mujeres
# Processing Record 29 of Set 11 | manoel urbano
# Processing Record 30 of Set 11 | calbuco
# Processing Record 31 of Set 11 | marsh harbour
# Processing Record 32 of Set 11 | taltal
# Processing Record 33 of Set 11 | awjilah
# Processing Record 34 of Set 11 | vacha
# Processing Record 35 of Set 11 | omboue
# Processing Record 36 of Set 11 | mosquera
# Processing Record 37 of Set 11 | pedernales
# Processing Record 38 of Set 11 | gargzdai
# Processing Record 39 of Set 11 | kisanga
# Processing Record 40 of Set 11 | marilandia
# Processing Record 41 of Set 11 | asilah
# Processing Record 42 of Set 11 | kilimatinde
# Processing Record 43 of Set 11 | sao raimundo nonato
# Processing Record 44 of Set 11 | bonthe
# Processing Record 45 of Set 11 | nikolskoye
# Processing Record 46 of Set 11 | florianopolis
# Processing Record 47 of Set 11 | pontal do parana
# Processing Record 48 of Set 11 | burgos
# Processing Record 49 of Set 11 | alta gracia
# Processing Record 50 of Set 11 | bousso
# Processing Record 1 of Set 12 | nokaneng
# Processing Record 2 of Set 12 | tucuman
# Processing Record 3 of Set 12 | springfield
# Processing Record 4 of Set 12 | gazanjyk
# Processing Record 5 of Set 12 | zhangye
# Processing Record 6 of Set 12 | geraldton
# Processing Record 7 of Set 12 | ekibastuz
# Processing Record 8 of Set 12 | yenagoa
# Processing Record 9 of Set 12 | eskisehir
# Processing Record 10 of Set 12 | jinka
# Processing Record 11 of Set 12 | ciudad ojeda
# Processing Record 12 of Set 12 | aljezur
# Processing Record 13 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 12 | celestun
# Processing Record 15 of Set 12 | garmsar
# Processing Record 16 of Set 12 | moose factory
# Processing Record 17 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 12 | chalus
# Processing Record 19 of Set 12 | pathein
# Processing Record 20 of Set 12 | ibra
# Processing Record 21 of Set 12 | castro marim
# Processing Record 22 of Set 12 | akdepe
# Processing Record 23 of Set 12 | mokhotlong
# Processing Record 24 of Set 12 | virginia beach
# Processing Record 25 of Set 12 | wajir
# Processing Record 26 of Set 12 | biarritz
# Processing Record 27 of Set 12 | tall kayf
# Processing Record 28 of Set 12 | sortland
# Processing Record 29 of Set 12 | lake city
# Processing Record 30 of Set 12 | puurmani
# Processing Record 31 of Set 12 | tabuk
# Processing Record 32 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | mantua
# Processing Record 34 of Set 12 | bonga
# Processing Record 35 of Set 12 | itajuipe
# Processing Record 36 of Set 12 | carman
# Processing Record 37 of Set 12 | vila velha
# Processing Record 38 of Set 12 | comodoro rivadavia
# Processing Record 39 of Set 12 | beira
# Processing Record 40 of Set 12 | rundu
# Processing Record 41 of Set 12 | wazzan
# City not found. Skipping...
# Processing Record 42 of Set 12 | skjervoy
# Processing Record 43 of Set 12 | natal
# Processing Record 44 of Set 12 | petrozavodsk
# Processing Record 45 of Set 12 | matamoros
# Processing Record 46 of Set 12 | santiago de cao
# Processing Record 47 of Set 12 | methoni
# Processing Record 48 of Set 12 | jakar
# Processing Record 49 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 12 | olinda
# Processing Record 1 of Set 13 | mattru
# Processing Record 2 of Set 13 | staraya mayna
# Processing Record 3 of Set 13 | pereira barreto
# Processing Record 4 of Set 13 | ouesso
# Processing Record 5 of Set 13 | eyrarbakki
# Processing Record 6 of Set 13 | odweyne
# Processing Record 7 of Set 13 | bogatyye saby
# Processing Record 8 of Set 13 | karasjok
# Processing Record 9 of Set 13 | leo
# Processing Record 10 of Set 13 | sabha
# Processing Record 11 of Set 13 | chichimila
# Processing Record 12 of Set 13 | mae hong son
# Processing Record 13 of Set 13 | angra
# City not found. Skipping...
# Processing Record 14 of Set 13 | stokmarknes
# Processing Record 15 of Set 13 | kashi
# Processing Record 16 of Set 13 | lopik
# Processing Record 17 of Set 13 | tacna
# Processing Record 18 of Set 13 | semaria
# Processing Record 19 of Set 13 | pirovskoye
# Processing Record 20 of Set 13 | hirtshals
# Processing Record 21 of Set 13 | uspenka
# Processing Record 22 of Set 13 | ulu-telyak
# Processing Record 23 of Set 13 | morondava
# Processing Record 24 of Set 13 | manga
# Processing Record 25 of Set 13 | xuddur
# Processing Record 26 of Set 13 | kuito
# Processing Record 27 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 13 | nador
# Processing Record 29 of Set 13 | chabahar
# Processing Record 30 of Set 13 | iranshahr
# Processing Record 31 of Set 13 | contamana
# Processing Record 32 of Set 13 | gat
# Processing Record 33 of Set 13 | yertsevo
# Processing Record 34 of Set 13 | badlapur
# Processing Record 35 of Set 13 | gao
# Processing Record 36 of Set 13 | alekseyevskaya
# Processing Record 37 of Set 13 | demyansk
# Processing Record 38 of Set 13 | aromashevo
# Processing Record 39 of Set 13 | duz
# City not found. Skipping...
# Processing Record 40 of Set 13 | nizwa
# Processing Record 41 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 42 of Set 13 | chanika
# Processing Record 43 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 13 | parambu
# Processing Record 45 of Set 13 | ostersund
# Processing Record 46 of Set 13 | havelock
# Processing Record 47 of Set 13 | tsaratanana
# Processing Record 48 of Set 13 | galveston
# Processing Record 49 of Set 13 | matara
# Processing Record 50 of Set 13 | capoterra
# Processing Record 1 of Set 14 | sao paulo de olivenca
# Processing Record 2 of Set 14 | fougeres
# Processing Record 3 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 14 | tahta
# Processing Record 5 of Set 14 | baghdad
# Processing Record 6 of Set 14 | nouakchott
# Processing Record 7 of Set 14 | watertown
# Processing Record 8 of Set 14 | gashua
# Processing Record 9 of Set 14 | mvangue
# Processing Record 10 of Set 14 | mount clemens
# Processing Record 11 of Set 14 | bafq
# Processing Record 12 of Set 14 | lucea
# Processing Record 13 of Set 14 | inhambane
# Processing Record 14 of Set 14 | la fria
# Processing Record 15 of Set 14 | grong
# Processing Record 16 of Set 14 | biryusinsk
# Processing Record 17 of Set 14 | bandundu
# Processing Record 18 of Set 14 | parabel
# Processing Record 19 of Set 14 | mbini
# Processing Record 20 of Set 14 | zachary
# Processing Record 21 of Set 14 | belmonte
# Processing Record 22 of Set 14 | villacarrillo
# Processing Record 23 of Set 14 | katima mulilo
# Processing Record 24 of Set 14 | sturgeon bay
# Processing Record 25 of Set 14 | miraflores
# Processing Record 26 of Set 14 | uarini
# Processing Record 27 of Set 14 | islamkot
# Processing Record 28 of Set 14 | motala
# Processing Record 29 of Set 14 | charagua
# Processing Record 30 of Set 14 | concepcion del uruguay
# Processing Record 31 of Set 14 | tokmak
# Processing Record 32 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 14 | dhanera
# Processing Record 34 of Set 14 | srimushnam
# Processing Record 35 of Set 14 | bad liebenwerda
# Processing Record 36 of Set 14 | guhagar
# Processing Record 37 of Set 14 | pangoa
# Processing Record 38 of Set 14 | geghamasar
# Processing Record 39 of Set 14 | pechenga
# Processing Record 40 of Set 14 | aberdeen
# Processing Record 41 of Set 14 | bull savanna
# Processing Record 42 of Set 14 | oparino
# Processing Record 43 of Set 14 | szany
# Processing Record 44 of Set 14 | oni
# Processing Record 45 of Set 14 | akhtubinsk
# Processing Record 46 of Set 14 | zabid
# Processing Record 47 of Set 14 | ottawa
# Processing Record 48 of Set 14 | iturama
# Processing Record 49 of Set 14 | karwar
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 2 of Set 15 | agadir
# Processing Record 3 of Set 15 | brownsville
# Processing Record 4 of Set 15 | mananara
# Processing Record 5 of Set 15 | grand haven
# Processing Record 6 of Set 15 | pinhao
# Processing Record 7 of Set 15 | ewo
# Processing Record 8 of Set 15 | chipinge
# Processing Record 9 of Set 15 | touros
# Processing Record 10 of Set 15 | tezu
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | chicama
# Processing Record 13 of Set 15 | sovetskaya
# Processing Record 14 of Set 15 | andenes
# Processing Record 15 of Set 15 | sabang
# Processing Record 16 of Set 15 | druzhba
# Processing Record 17 of Set 15 | lukulu
# Processing Record 18 of Set 15 | saint-georges
# Processing Record 19 of Set 15 | saint anthony
# Processing Record 20 of Set 15 | sangod
# Processing Record 21 of Set 15 | adilabad
# Processing Record 22 of Set 15 | novara
# Processing Record 23 of Set 15 | forio
# Processing Record 24 of Set 15 | monrovia
# Processing Record 25 of Set 15 | muros
# Processing Record 26 of Set 15 | bobo dioulasso
# Processing Record 27 of Set 15 | port-gentil
# Processing Record 28 of Set 15 | bama
# Processing Record 29 of Set 15 | dhidhdhoo
# Processing Record 30 of Set 15 | lungi
# Processing Record 31 of Set 15 | dabakala
# Processing Record 32 of Set 15 | rio gallegos
# Processing Record 33 of Set 15 | sivota
# Processing Record 34 of Set 15 | nantucket
# Processing Record 35 of Set 15 | corralillo
# Processing Record 36 of Set 15 | bergen
# Processing Record 37 of Set 15 | rondonopolis
# Processing Record 38 of Set 15 | foumbot
# Processing Record 39 of Set 15 | narkanda
# Processing Record 40 of Set 15 | beloye
# Processing Record 41 of Set 15 | djambala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jacobina      BR -11.1806  -40.5183     76.75        36          12
# 1     Tocopilla      CL -22.0920  -70.1979     62.91        66          15
# 2      Tasiilaq      GL  65.6145  -37.6368     32.16        54          71
# 3     Jamestown      US  42.0970  -79.2353     64.04        59           0
# 4       Ushuaia      AR -54.8000  -68.3000     49.66        50          40
# 5         Vagur      FO  61.4732   -6.8119     49.14        80          33
# 6  Richards Bay      ZA -28.7830   32.0377     70.43        92          49
# 7     Busselton      AU -33.6500  115.3333     52.20        62          10
# 8    Big Rapids      US  43.6981  -85.4837     68.07        42           0
# 9       Vierzon      FR  47.2101    2.0625     60.35        89           4
#
#    Wind Speed Current Description
# 0        5.86          few clouds
# 1       14.03          few clouds
# 2        5.57       broken clouds
# 3        5.75           clear sky
# 4        9.22    scattered clouds
# 5       35.70    scattered clouds
# 6        8.23    scattered clouds
# 7        7.99           clear sky
# 8        3.44           clear sky
# 9        8.81           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jacobina      BR -11.1806  -40.5183     76.75        36          12
# 1     Tocopilla      CL -22.0920  -70.1979     62.91        66          15
# 2      Tasiilaq      GL  65.6145  -37.6368     32.16        54          71
# 3     Jamestown      US  42.0970  -79.2353     64.04        59           0
# 4       Ushuaia      AR -54.8000  -68.3000     49.66        50          40
# 5         Vagur      FO  61.4732   -6.8119     49.14        80          33
# 6  Richards Bay      ZA -28.7830   32.0377     70.43        92          49
# 7     Busselton      AU -33.6500  115.3333     52.20        62          10
# 8    Big Rapids      US  43.6981  -85.4837     68.07        42           0
# 9       Vierzon      FR  47.2101    2.0625     60.35        89           4
#
#    Wind Speed Current Description
# 0        5.86          few clouds
# 1       14.03          few clouds
# 2        5.57       broken clouds
# 3        5.75           clear sky
# 4        9.22    scattered clouds
# 5       35.70    scattered clouds
# 6        8.23    scattered clouds
# 7        7.99           clear sky
# 8        3.44           clear sky
# 9        8.81           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
